# %% [markdown]
# ## Shaking Earth

# %% [markdown]
# ### What is this competition all about?
#
# * Given seismic signals we are asked to predict the time untile the onset of laboratory earthquakes.
#
# * The training data is a single sequence of signal and seems to come from one experiment alone.
#
# * In contrast the test data consists of several different sequences, called segments, that may correspond to different experiments. The regular pattern we might find in the train set does not match those of the test segments.
#
# * For each test data segment with its corresponding seg_id, we are asked to predict it's single time until the lab earthquake takes place.

# %%
## Loading Packages

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt


import seaborn as sns
sns.set()

from IPython.display import HTML

from os import listdir
print(listdir("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Datasets/LANL Earthquake Prediction"))

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# ['sample_submission.csv', 'train.csv', 'test']

# %% [markdown]
# ### What is an earthquake in the lab?
#
# Currently I do not know how an earthquake in the lab works and as I googled around, I found this interesting video that shows how such a lab looks like. If you want to know more, this video is a good start. I am still on my journey to understand the problem.

# %%
HTML ('<iframe width="600" height="300" src="https://www.youtube.com/embed/m_dBwwDJ4uo" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="600" height="300" src="https://www.youtube.com/embed/m_dBwwDJ4uo" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# In the end we can see that the probes that are used are put under some kind of normal pressure but there is a shear stress working on it as well. Then, after some time, the probe splits. If we take a look at the additional material given, you can see that we have:
#
# **3 kinds of plates**
#
# * 2 plates left and right that are under normal pressure: Forces are acting with 90 degrees on the plate, pushing the two plates together.
#
# * In the middle we find a third plate which is separated by some granular material. This plate moves downwards with constant velocity.
#
# To develop an intuition, it seems that this granular material is the "rock" that can split and load again to produce this kind of lab earthquakes in repititive cycles. Even though the train set contains continuous data it contains several such splits (earthquakes).

# %% [markdown]
# ### Let's get familiar with the data!

# %% [markdown]
# ### Training data
# The total size of the training data is almost 9 GB and we do not want to wait too long just for a first impression, let's load only some rows:

# %%
train = pd.read_csv("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Datasets/LANL Earthquake Prediction/train.csv",
                    nrows = 10000000, dtype={'acoustic_data': np.int16, 'time_to_failure': np.float64})
train.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691

# %% [markdown]
# We can see two columns: Acoustic_data and time_to_failure. The former is the seismic signal, and the latter is the time until the laboratory earthquake takes place. Let's rename the columns for simplicity.

# %%
train.rename({"acoustic_data": "signal", "time_to_failure": "quaketime"}, axis = "columns", inplace=True)
train.head()
# Out:
#    signal  quaketime
# 0      12     1.4691
# 1       6     1.4691
# 2       8     1.4691
# 3       5     1.4691
# 4       8     1.4691

# %% [markdown]
# We can see that the quaketime of these first rows seems to be always the same. But is it really true?

# %%
for n in range(5):
  print(train.quaketime.values[n])
# Out:
# 1.4690999832
# 1.4690999821
# 1.469099981
# 1.4690999799
# 1.4690999788

# %% [markdown]
# Aha! We can see that they are not the same and that pandas has rounded them off. Also we can see that the time seems to decrease. Let's plot the time to get more familiar with this pattern:

# %%
fig, ax = plt.subplots(2,1,figsize=(20,12))
ax[0].plot(train.index.values, train.quaketime.values, c = "darkred")
ax[0].set_title("Quaketime of 10 Mio rows")
ax[0].set_xlabel("Index")
ax[0].set_ylabel("Quaketime in ms:");

ax[1].plot(train.index.values, train.signal.values, c="mediumseagreen")
ax[1].set_title("Signal of 10 Mio rows")
ax[1].set_xlabel("Index")
ax[1].set_ylabel("Acoustic Signal")
# Out:
# Text(0, 0.5, 'Acoustic Signal')

# %% [markdown]
# ### Take-Away
#
# * We can see only one time in 10 Mio rows when quaktime goes to 0. This is a timepoint where an earthquake in the lab occurs.
#
# * There are many small oscillations until a heavy peak of the signal occurs. Then it takes some time with smaller oscillations and the earthquake occurs.
#
# If we take a look at the first 50000 indices we can see that there is a second pattern of quaketime that has something to do with the resolution of the experiment equipment:

# %%
fig, ax = plt.subplots(3,1,figsize=(20,18))
ax[0].plot(train.index.values[0:50000], train.quaketime.values[0:50000], c="Red")
ax[0].set_xlabel("Index")
ax[0].set_ylabel("Time to Quake")
ax[0].set_title("How does the second quaketime pattern look like?")

ax[1].plot(train.index.values[0:49999], np.diff(train.quaketime.values[0:50000]))
ax[1].set_xlabel("Index")
ax[1].set_ylabel("Difference between Quaketimes")
ax[1].set_title("Are the jumps always the same?")

ax[2].plot(train.index.values[0:4000], train.quaketime.values[0:4000])
ax[2].set_xlabel("Index from 0 to 4000")
ax[2].set_ylabel("Quaketime")
ax[2].set_title("How does the quaktime changes within the first block?");

# %% [markdown]
# ### Take-Away
#
# Very interesting
#
# 1. The first plot shows that the quaketime seems to stay almost constant up to index 4000. Then a step occurs, afterwards this kind of pattern repeats.
#
# 2. The second plot reveals that the second jump of the quaketime is larger than the first.
#
# 3. The third plot shows that the quaketime within such a "constant" block is not really constant but linearly decreasing even though with very small numbers.

# %% [markdown]
# ### First Conclusion
#
# Total there are 16 earthquakes in the train set and they really occur when quaktime goes to 0. It is still interesting why we have several blocks and jumps of quaketime on low resolution where the time decreases linearly with a very small stepsize.
#
# Currently I am not sure why these jumps between our target quaketime occur between values with only small scaled differences?
#
# Now we have become familiar with the train data, let,s turn to the test data before switching to more explorations.
#
# ### Test data
#
# We can find multiple segments of sequences in the test folder. Let's peek at their names:

# %%
test_path = "/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Datasets/LANL Earthquake Prediction/test/"
test_files = listdir("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Datasets/LANL Earthquake Prediction/test")
print(test_files[0:5])
# Out:
# ['seg_a16a1b.csv', 'seg_a1acb2.csv', 'seg_a18246.csv', 'seg_a03e6a.csv', 'seg_a3d4d6.csv']

# %% [markdown]
# How many segments do we have?

# %%
len(test_files)
# Out:
# 2624

# %% [markdown]
# Does it match with the number of seg_ids in the sample submission?

# %%
sample_submission = pd.read_csv("/content/drive/MyDrive/Data Science WorkSpace/Machine Learning Projects/Datasets/LANL Earthquake Prediction/sample_submission.csv")
sample_submission.head()
# Out:
#        seg_id  time_to_failure
# 0  seg_00030f                0
# 1  seg_0012b5                0
# 2  seg_00184e                0
# 3  seg_003339                0
# 4  seg_0042cc                0

# %%
len(sample_submission.seg_id.values)
# Out:
# 2624

# %% [markdown]
# Ok, how does the signal of the test data look like?

# %%
fig, ax = plt.subplots(4, 1, figsize= (20, 25))

for n in range(4):
  seg = pd.read_csv(test_path + test_files[n])
  ax[n].plot(seg.acoustic_data.values, c="mediumseagreen")
  ax[n].set_xlabel("Index")
  ax[n].set_ylabel("Signal")
  ax[n].set_ylim([-300, 300])
  ax[n].set_title("Test {}".format(test_files[n]));

# %% [markdown]
# ### Take-Away
#
# * These test segment examples differ a lot in the occurences of small peaks that seem to be similar to those in the train data before and after the heavy
# signal peak that occured some time before the lab earthquake took place.
#
# * They probably came from the same experiment but do neither form a continuous signal nor directly follow after the train data.

# %% [markdown]
# ### A Question Collection
#
# Even though there is only one signal feature and one target column, there is so much we need to understand and explore. Before we add more features, it's probably better to work with what is given so far. Let's try to answer some questions that can provide us some more information.

# %% [markdown]
# ### Questions for the train set
#
# * Why do we have this low resolution jumps and why are they different? Is there some periodicity that may correlate with the signal? Would it be helpful to reconstruct that for test segments?
#
# * Why do we only have 16 earthquakes and such a high resolution of signal in between?

# %% [markdown]
# ### Questions for the test set
#
# * Are all segments of the test set of the same length?
#
# * Are they similar in their distributions or in the strength and time period between strong peaks?
#
# * Can we find some groups of similar test set segments?

# %% [markdown]
# ### A jump into train explorations

# %%
train.describe()
# Out:
#              signal     quaketime
# count  1.000000e+07  1.000000e+07
# mean   4.502072e+00  5.183598e+00
# std    1.780707e+01  5.091286e+00
# min   -4.621000e+03  7.954798e-04
# 25%    2.000000e+00  6.498971e-01
# 50%    4.000000e+00  1.298899e+00
# 75%    7.000000e+00  1.089170e+01
# max    3.252000e+03  1.154080e+01

# %% [markdown]
# * We can see that the mean is shifted towards higher values due to earthquake. In addition we can see that the 25% up to 75% quartiles are looking very discrete.
#
# * Looking at the quake time we can't say much about it.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,5))
sns.distplot(train.signal.values, ax=ax[0], color="Red", bins=100, kde=False)
ax[0].set_xlabel("Signal")
ax[0].set_ylabel("Density")
ax[0].set_title("Signal Distribution")

low = train.signal.mean() - 3 * train.signal.std()
high = train.signal.mean() + 3 * train.signal.std()
sns.distplot(train.loc[(train.signal >= low) & (train.signal <= high), "signal"].values,
             ax=ax[1],
             color="Orange",
             bins=150,
             kde=False)

ax[1].set_xlabel("Signal")
ax[1].set_ylabel("Density")
ax[1].set_title("Signal Distribution Without Peaks");

# %% [markdown]
# ### Take-Away
#
# * In the first plot we can see that **the earthquake causes very high outlier values.** This way we can't say much about the signal distribution close to zero.
#
# * The second plot shows the signal at the median and mean around 4. We can see that it **looks very gaussian and balanced. It seems that the signal is somehow discrete.**

# %% [markdown]
# ### The stepsize
#
# By computing the difference between two earthquakes we obtain some kind of stepsize that is probably equal within blocks and can show us the jump strength between different quaketime. The following code computes differences first and drops the last row of train such that we can add the stepsize to the data. I think we won't lose fruitful information this way.

# %%
stepsize = np.diff(train.quaketime)
train = train.drop(train.index[len(train) - 1])
train['stepsize'] = stepsize
train.head()
# Out:
#    signal  quaketime      stepsize
# 0      12     1.4691 -1.100000e-09
# 1       6     1.4691 -1.100000e-09
# 2       8     1.4691 -1.100000e-09
# 3       5     1.4691 -1.100000e-09
# 4       8     1.4691 -1.100000e-09

# %%
train.stepsize = train.stepsize.apply(lambda x: np.round(x, 10))

# %%
stepsize_counts = train.stepsize.value_counts()
stepsize_counts
# Out:
# -1.100000e-09    5655193
# -1.000000e-09    3907597
# -2.000000e-09     434767
# -1.095496e-03        882
# -1.095495e-03        679
# -9.954955e-04        497
# -9.954950e-04        381
# -1.095497e-03          1
#  1.154000e+01          1
# Name: stepsize, dtype: int64

# %% [markdown]
# Still Strange! ** The stepsize within two quaketimes is often given by either -1, -1, 1 or -2ns**. In addition we have ** stepsize close to -0.9955 ms ** Do you see it? Its something centered at -1 ms. As we have one earthquake in train the **heavy stepsize of 11.5 is the step between the earthquake and a new cycle** that goes on until the next earthquake occurs.

# %% [markdown]
# ### Setting up a validation strategy
#
# In our opinion, it does not make sense to split the rows of the train data randomly to obtain validation data. This is temporal data and in the test segments we probably do not have any future values given. In the decription we can read : "The training data is a single , continuous segment of experimental data. The test data consists of a folder containing many small segments. The data within each test file is continuous, but the test files do not represent a continuous segment of the experiment; thus, the predictions cannot be assumed to follow the same regular pattern seen in the training file." What does this mean for us? Let's imagine some scenarios:

# %% [markdown]
# ### Scenario A
#
# * The cycles in the train data are independent of each other.
#
# * If there was already an earthquake, ** this does not change the material** in its fault behaviors.
#
# * Let's suppose the **test data uses the same experimental setup.**
#
# If this is true, it is not important that we need a second (or multiple) experiment to generate test data. We could only do one experiment and cut out segments to produce different data snippets. As this does not fit well to the description of the data ** this scenario is not likely.**
#
#
# ### Scenario B
#
# * The cycles depend on each other. There is temporal correlation of future signals with past ones.
#
# * The ** material changes somehow from cycle to cycle** and perhaps future cycles are clearly different from past ones.
#
# * The **test data** uses the **same experimental setup** but to prevent leakage there were **at least one new experiment** done to produce segments that may depend on each other, e.g some of them may have temporal correlations.
#
# * To make it more tricky there are **only some snippets given in the test data whereas others are simply dropped**.
#
# In this case we need a model that is able to capture the temporal dependence of cycles and it should be able to make nice predictions for different cycles. As we need to make predictions for several different cycle-phases it could be fruitful to use some kind of rolling window validation.
#
#
# ### Scenario C
#
# * The **cycles depend on each other**. There is temporal correlation of future signals with past ones.
#
# * The state of the **material changes from cycle to cycle**.
#
# * The **test data uses experimental setups that are different from the train data generation** process. In the worst case we have multiple different experiments that produce test data.
#
# * To make it more tricky there are **only some snippets given in the test data whereas others are simply dropped.**

# %% [markdown]
# ### How to split now?
#
# Lets go with Scenario B ,for which there is a scikit-learn implementation that may help. But before we go on, the **test set does not contain any earthquakes. Hence it's perhaps not a good idea to include them during training and validation**. In training they would cause extreme target outliers of quaketime. Our model may always try to match its predictions with these targets and this would hinder learning for the relevant parts, for those kind of predictions with these targets and this would hinder learning for the relevant parts, for those kind of predictions we need for the test set.

# %%
from sklearn.model_selection import TimeSeriesSplit

cv = TimeSeriesSplit(n_splits=5)

# %% [markdown]
# ### Rolling features
#
# Lets extract the features by a rolling window approach and make some visualizations on these features for data before the first earthquake occurence.
#
# ### Window size
#
# Window size is a hyperparameter that can be optimized , let's start with different sizes :

# %%
window_sizes = [10, 50, 100, 1000]

for window in window_sizes:
  train['rolling_mean_' + str(window)] = train.signal.rolling(window=window).mean()
  train['rolling_std_' + str(window)] = train.signal.rolling(window=window).std()

# %%
fig, ax = plt.subplots(len(window_sizes), 1, figsize=(20, 6*len(window_sizes)))

n = 0
for col in train.columns.values:
  if "rolling_" in col:
    if "mean" in col:
      mean_df = train.iloc[4435000:4445000][col]
      ax[n].plot(mean_df, label=col, color="mediumseagreen")
    if "std" in col:
      std = train.iloc[4435000: 4445000][col].values
      ax[n].fill_between(mean_df.index.values, 
                         mean_df.values - std, 
                         mean_df.values + std,
                         facecolor="lightgreen",
                         alpha=0.5,
                         label=col)
      ax[n].legend()
      n += 1

# %% [markdown]
# A window size of 50 locks good enough to cover most fluctuations in sufficient detail without averaging out important signals.
#
# ### Statistical Features
#
# Now that we have found a first choice for the window size, let's compute some basic rolling statistical features:
#
# * mean
# * standard deviation
# * 25% quartile
# * 50% quartile (median)
# * 75% quartile
# * interquartile range (75% - 25%)
# * min
# * max
# * skewness
# * kurtosis
#
# Just for curiosity let's keep the mean and std for the window sizes we have excluded from above. Perhaps we can see later that these features were more important than the 50-size-window-features.

# %%
train['rolling_q25'] = train.signal.rolling(window=50).quantile(0.25)
train['rolling_q75'] = train.signal.rolling(window=50).quantile(0.75)
train['rolling_q50'] = train.signal.rolling(window=50).quantile(0.5)
train['rolling_iqr'] = train.rolling_q75 - train.rolling_q25
train['rolling_min'] = train.signal.rolling(window=50).min()
train['rolling_max'] = train.signal.rolling(window=50).max()
train['rolling_skew'] = train.signal.rolling(window=50).skew()
train['rolling_kurt'] = train.signal.rolling(window=50).kurt()

# %% [markdown]
# ### The End :)
